# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadRidwanPermana/MuhamadRidwanPermana.github.io/blob/main/UAS_VD_MuhamadRidwanPermana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import PercentFormatter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#  menapilkan kebutuhan bulanan

# %%
df = pd.read_csv('content/kebutuhan_per_bulan_2.csv')

# %%
df_kbulanan
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %% [markdown]
# SCATER PLOT 1 KEBUTUHAN PERTAHUN BERDASARKAN SEMUA PROVINSI

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Propinsi'], df['tahun'], s=50, c='blue', alpha=0.7)

for i in range(len(df)):
    plt.annotate(df['kebutuhan'][i], (df['Propinsi'][i], df['tahun'][i]), ha='center', va='bottom', fontsize=8)

plt.title('Plot 1 - Kebutuhan Per Tahun Berdasarkan Semua Provinsi', fontsize=18)
plt.xlabel('Propinsi', fontsize=12)
plt.ylabel('Tahun', fontsize=12)

plt.xticks(rotation=90, fontsize=8)

plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# SCATER PLOT 2 KEBUTUHAN PERTAHUN BERDASARKAN SPESIFIK PROVINSI BANTEN

# %%
df = pd.DataFrame(df_kbulanan)
# scatter plot 1 hanya menampikan kebutuhan tahunan dari 1 provinsi
spesifik_provinsi = 'BANTEN'
df_spesifik_provinsi = df.loc[df['Propinsi'] == spesifik_provinsi]

x = df_spesifik_provinsi['tahun']
y = df_spesifik_provinsi['kebutuhan']

plt.title(f'PLOT 2 - STATISTIK KEBUTUHAN {spesifik_provinsi}')
plt.xlabel("Tahun")
plt.ylabel("Kebutuhan")

plt.scatter(x, y, color='#D04', marker='s')

plt.xlim(min(x), max(x))
# Menampilkan data provinsi tertentu

plt.show()

# %% [markdown]
# Sacatter 3 - Menampilkan data transaksi

# %%
df_transaksi = pd.read_csv("/content/transaksi2.csv", names=['date', 'id_product', 'quantity', 'id_penjualan'])
df_transaksi
# Out:
#                      date id_product  quantity  id_penjualan
# 0     2017-05-03 11:43:20      22704        25         15572
# 1     2017-09-04 07:16:20      22081        10         12461
# 2     2017-07-09 11:39:20      22989       100         12590
# 3     2017-03-20 12:18:20      22629        64         16839
# 4     2018-01-24 08:50:20      21615         1         13596
# ...                   ...        ...       ...           ...
# 7464  2018-01-24 09:17:20      22510         1         18156
# 7465  2018-02-02 09:49:20      20771         2         14606
# 7466  2017-03-23 12:52:20      22493        12         17001
# 7467  2017-10-25 10:28:20      23118         2         15856
# 7468  2017-07-19 09:54:20      23184         2         14769
#
# [7469 rows x 4 columns]

# %%
df_transaksi['date'] = pd.to_datetime(df_transaksi['date'])
df_transaksi['year'] = df_transaksi['date'].dt.year
df_transaksi['month'] = df_transaksi['date'].dt.month_name()
df_clean = df_transaksi.loc[df_transaksi['year'] == 2018]
df_clean

plt.title('PLOT 3 - MENAMPILKAN DATA TRANSAKSI')
plt.scatter(df_clean['date'], df_clean['quantity'])

plt.xlabel('Date')
plt.ylabel('Quantity')

plt.show()

# %% [markdown]
# Sacatter 4 - Transaksi pada tahun 2018

# %%
df_transaksi['date'] = pd.to_datetime(df_transaksi['date'])
df_transaksi['year'] = df_transaksi['date'].dt.year
df_transaksi['month'] = df_transaksi['date'].dt.month_name()
df_clean = df_transaksi.loc[df_transaksi['year'] == 2018]
# Melakukan pengelompokan dan penghitungan
plt.title('PLOT 4 - MENAMPILKAN DATA TRANSAKSI TAHUN 2018')
df_count = df_clean.groupby('month').count()
# Menampilkan scatter plot
plt.scatter(df_count['date'], df_count.index)

# %%
df = pd.read_csv('content/SupplyKantor.csv')

# %%
print(df)
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %% [markdown]
# SCATER 5 - JUMLAH PESANAN SETIAP KOTA

# %%
x = df['Kota']
y = df['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)

plt.xlabel('Kota')
plt.ylabel('Jumlah')

plt.title('Plot 5 - Jumlah Pesanan dari Setiap Kota')

plt.show()

# %%
data_filtered = df [df['Kota']=='Surabaya']
data_filtered
# Out:
#    TanggalPesan      Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 1     07-Apr-17  Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17  Surabaya     Nono  Pen Set      55         12490
# 4     03-May-17  Surabaya    Mamat  Pen Set      42         23950
# 16    13-Aug-17  Surabaya     Alex   Binder      11          4990
# 17    21-Aug-17  Surabaya    Mamat  Pen Set      96          4990
# 18    30-Aug-17  Surabaya     Alex   Binder      94         19990
# 24    19-Oct-17  Surabaya    Mamat   Binder      50         19990
# 26    05-Nov-17  Surabaya     Alex   Pencil      36          4990
# 31    18-Dec-17  Surabaya     Alex  Pen Set      50          4990
# 35    21-Jan-18  Surabaya     Nono      Pen      96          4990
# 36    29-Jan-18  Surabaya     Alex   Pencil      90          4990
# 41    13-Mar-18  Surabaya    Mamat     Desk       5        125000

# %%
x = data_filtered['Jenis']
y = data_filtered['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Jenis Barang')
plt.ylabel('Jumlah')

plt.title('PLOT 6 - Jumlah Pesanan dari Kota Surabaya')

plt.show()

# %%
df = pd.read_csv('content/profile_pelanggan.csv')

# %%
print(df)
# Out:
#       15572  DKI Jakarta
# 0     12461   Jawa Timur
# 1     12590   Jawa Barat
# 2     16839  DKI Jakarta
# 3     13596  DKI Jakarta
# 4     12395    Luar Jawa
# ...     ...          ...
# 2352  18261  DKI Jakarta
# 2353  18257  DKI Jakarta
# 2354  12510  Jawa Tengah
# 2355  16198  DKI Jakarta
# 2356  16235  DKI Jakarta
#
# [2357 rows x 2 columns]
